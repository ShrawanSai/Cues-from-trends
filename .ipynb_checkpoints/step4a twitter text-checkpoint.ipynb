# %% [markdown]
# #### Step 4a: Twitter

# %%
#importing all dependencies
import numpy as np
import tweepy

from datetime import datetime, timedelta
import time

from tweepy import OAuthHandler
from tweepy import API


#Define your keys from the developer portal
consumer_key="pCx9D6iouX8za05ijzYGTP7aA"
consumer_secret="usevYFDTLePAwkjRtFdLcIoFbFdtZM4mGygkUpOsC1slvMQVjY"
access_key="1071084889154310145-PW13NCjmNLWtk5i8YPckRRnhIgcUD0"
access_secret="UapYLhcTiZ77ztOLqsfe1eCAZMBSpo85NORHq9nNwY2XK"

# %%
file_name = 'step3_data.pkl'
df = pd.read_pickle(file_name)

# %%
class TwitterStreamListener(tweepy.streaming.StreamListener):
    
    count = 0
    tweets = set()

    
    ''' Handles data received from the stream. '''
    

        
    def get_ready(self):
        TwitterStreamListener.count = 0
        TwitterStreamListener.end_time = 0
        TwitterStreamListener.tweets = set()

        
    def on_status(self, status):
        
        #print(f'ID: {status.id}')
        #print(f'Username: {status.user.name}')
        #print(datetime.today())
        

        
        days_old = (datetime.today() - status.created_at).days
        favorites = status.favorite_count
        lang = status.lang
        retweet_count = status.retweet_count
        
        
        if days_old<30 and lang == 'en':
            TwitterStreamListener.tweets.add(status.text)
            TwitterStreamListener.count += 1
        if TwitterStreamListener.count >=5:
            return False
        
        return True

    def on_error(self, status_code):
        print('Got an error with status code: ' + str(status_code))
        if int(status_code) == 420:
            print('sleeping')
            time.sleep(5)
        return True # To continue listening

    def on_timeout(self):
        print('Timeout...')
        return False # To continue listening

# %%
listener = TwitterStreamListener()
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)

# %%
def scrape_tweets(keyword):
    listener.get_ready()
    stream = tweepy.streaming.Stream(auth, listener,timeout=15)
    stream.filter(track=[keyword])
    return list(listener.tweets)

# %%
#scrape_tweets('Harbhajan Singh')

# %%
titles = ['#1YearOfITABestJodiAshDeep',
 '#BJPSweepsGujarat',
 '#Bigil',
 '#BiharElectionResults',
 '#BiharElections2020',
 '#BiharResult',
 '#BoycottAmazon',
 '#Congress',
 '#DubbakaBypolls',
 '#ElectionResults',
 '#Ganapath',
 '#HappyBirthdayKrish',
 '#IPLfinal',
 '#KarnatakaBypollResults',
 '#MadhyaPradesh',
 '#Nov10WithArnab',
 '#PSPK27',
 '#PhotoThaakku',
 '#ReleaseArnabVoiceOfSSR',
 '#ResultsWithNDTV',
 '#WorldScienceDay',
 '#byelection2020',
 '#pushparajhuntbegins',
 '#tuesdayvibe',
 'Armenia',
 'Assembly',
 'Biharis',
 'Burnol',
 'Chirag',
 'Exit Polls',
 'GOOD AIR MOVEMENT',
 'Harbhajan Singh',
 'India Today',
 'Mahagathbandhan',
 'Nitish',
 'Only 20%',
 'Ravish Kumar',
 'Rona',
 'SidNaaz Craze',
 'Starc',
 'Sushil Modi',
 'Tej Pratap Yadav',
 'Tejaswi',
 'Telangana',
 'bighit',
 'darr']

# %%
# %%time
#titles = titles[:5]
mapping = {}
c = 1
for title in df['title']:
    hasht = title
    if c!=1:
        time.sleep(3)
    if c%7 == 0:
        print('sleeping')
        time.sleep(5)
    print(title)
    try:
        t = scrape_tweets(title)
    except Exception as e:
        print(e)
        t = []
    print( f'Found {len(t)} tweets')
    c += 1
    #print('done searching')
    
    if len(t)<1:
        continue
        '''if title.startswith('#'):

            title = title[1:]
            title = re.findall(r'[A-Z](?:[a-z]+|[A-Z]*(?=[A-Z]|$))', title)
            if len(title)<1: 
                continue
            title = ' '.join(title)
            print('searching hashtag')
            t += scrape_tweets(title)
            print('done searching')'''
        
        
        
    mapping.update({hasht:t})
# Out:
# #DubbakaBypolls
# Found 5 tweets
# #IrandamKuththu
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Bihar Assembly
# Found 4 tweets
# NEET results
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# #BiharElectionResults
# Found 5 tweets
# bighit
# Found 4 tweets
# sleeping
# Shikhar Dhawan
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Jaipur
# Found 4 tweets
# Sira
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Starc
# Found 4 tweets
# #BoycottAmazon
# Found 4 tweets
# EVMs
# Found 5 tweets
# Exit
# Found 5 tweets
# sleeping
# #MouseHunt
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# #Bigil
# Found 4 tweets
# #BiharResult
# Found 4 tweets
# Jharkhand
# Found 5 tweets
# Sushil Modi
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Captain Marvel
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Kabir Singh
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# sleeping
# Avengers: Endgame
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Lok Sabha Elections
# Got an error with status code: 420
# sleeping
# ('Connection broken: OSError("(10054, \'WSAECONNRESET\')",)', OSError("(10054, 'WSAECONNRESET')",))
# Found 0 tweets
# Cricket World Cup
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# #IPLUnacademyVideo
# Got an error with status code: 420
# sleeping
# Found 5 tweets
# Article 370
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Harbhajan Singh
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# India Today
# Got an error with status code: 420
# sleeping
# Found 5 tweets
# sleeping
# Joker
# Found 5 tweets
# Chandrayaan 2
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# PM Kisan Yojana
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# #Congress
# Got an error with status code: 420
# sleeping
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Owaisi
# Got an error with status code: 420
# sleeping
# Found 5 tweets
# Yogendra Yadav
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Burnol
# Got an error with status code: 420
# sleeping
# Found 5 tweets
# sleeping
# NDTV
# Found 5 tweets
# Mozambique
# Found 5 tweets
# #WorldScienceDay
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Rona
# Got an error with status code: 420
# sleeping
# Found 5 tweets
# Mahagathbandhan
# Found 5 tweets
# Nitish
# Found 5 tweets
# Armenia
# Found 5 tweets
# sleeping
# Only 20%
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# #BiharElections2020
# Found 5 tweets
# good air movement
# HTTPSConnectionPool(host='stream.twitter.com', port=443): Read timed out.
# Found 0 tweets
# Wall time: 27min 58s

# %%
df['Tweets'] = df['title'].map(mapping)

# %%
df
# Out:
#                     title  popularity                            Type  \
# 0         #DubbakaBypolls   99.000000                         hashtag
# 1         #IrandamKuththu   77.141566                         hashtag
# 2          Bihar Assembly   63.786451                           Topic
# 3            NEET results   48.965465            Entrance examination
# 4   #BiharElectionResults   47.482541                         hashtag
# 5                  bighit   46.416561                         Company
# 6          Shikhar Dhawan   43.898400                Indian cricketer
# 7                  Jaipur   42.561668                   City in India
# 8                    Sira   40.754191                   City in India
# 9                   Starc   35.165562                            Food
# 10         #BoycottAmazon   35.163418                         hashtag
# 11                   EVMs   33.421953                           Topic
# 12                   Exit   33.199002                        Festival
# 13             #MouseHunt   32.964058                         hashtag
# 14                 #Bigil   31.861591                         hashtag
# 15           #BiharResult   31.824801                         hashtag
# 16              Jharkhand   31.816582                  State of India
# 17            Sushil Modi   31.658548  Deputy Chief Minister of Bihar
# 18         Captain Marvel   31.614165                            Film
# 19            Kabir Singh   31.480038               Indian film actor
# 20      Avengers: Endgame   31.480038                       2019 film
# 21    Lok Sabha Elections   31.480038                General election
# 22      Cricket World Cup   31.480038              Cricket tournament
# 23     #IPLUnacademyVideo   31.480038                         hashtag
# 24            Article 370   31.480038                           Topic
# 25        Harbhajan Singh   31.430169                Indian cricketer
# 26            India Today   31.261390                        Magazine
# 27                  Joker   31.196597                       Character
# 28          Chandrayaan 2   31.143488                   Space mission
# 29        PM Kisan Yojana   31.009227                         hashtag
# 30              #Congress   30.863841                         hashtag
# 31                 Owaisi   30.829260            Member of parliament
# 32         Yogendra Yadav   30.706607               Indian Politician
# 33                 Burnol   30.365100                         hashtag
# 34                   NDTV   30.328554                         Company
# 35             Mozambique   30.099982          Country in East Africa
# 36       #WorldScienceDay   29.897603                         hashtag
# 37                   Rona   29.117655                  Retail company
# 38        Mahagathbandhan   28.554125                           Bihar
# 39                 Nitish   28.084833         Chief Minister of Bihar
# 40                Armenia   16.538451                 Country in Asia
# 41               Only 20%   16.253097                           Topic
# 42    #BiharElections2020   14.557287                         hashtag
# 43      good air movement    1.000000                           Topic
#
#                                        Related Topics  \
# 0                                                 NaN
# 1           [Kuththu, Film, Irandam Ulagam, Download]
# 2   [Kasturbhai Lalbhai, Constituent Assembly of I...
# 3       [2017, NEET · 2017, NEET · 2019, NEET · 2018]
# 4   [2017, Amethi, United States presidential elec...
# 5       [GFriend, Seventeen, Concert tour, Blackpink]
# 6   [Hardik Pandya, Rishabh Pant, 2019 ICC Cricket...
# 7   [Sapna Choudhary, Dupatta, Jaipur Pink Panther...
# 8   [Needham, Sye Raa Narasimha Reddy, Somerville,...
# 9   [2018 Indian Premier League, 2016 Indian Premi...
# 10  [Donald Trump, Amazon Prime, National Rifle As...
# 11  [Enterprise Volume Management System, Parliame...
# 12  [2018 Italian general election, Brexit, Escape...
# 13  [OCBC Bank, Mickey's Treasure Hunt, Sinhala la...
# 14     [Tamil language, Vijay, Review, Tamil Rockers]
# 15  [2017, CBSE Class 12th · 2017, CBSE Class 10th...
# 16  [Lockdown, Dhadkan, Twenty20, Pradhan Mantri A...
# 17  [Tejashwi Yadav, Tej Pratap Yadav, Member of P...
# 18  [Alita: Battle Angel, Goose, Brie Larson, Gemm...
# 19  [Arjun Reddy, Magnet URI scheme, Super 30, Tam...
# 20      [Box office, Ticket, Casting, Captain Marvel]
# 21       [Green Revolution, Mandya, Vellore, Wayanad]
# 22  [2017 Women's Cricket World Cup, 2018 Under-19...
# 23                                                NaN
# 24  [Quantum, Satyendra Nath Bose, Quantum mechani...
# 25  [2018 Indian Premier League, Hardik Pandya, Th...
# 26  [Coronavirus, Lockdown, Worldometers, 2019 ICC...
# 27  [Joaquin Phoenix, Persona 5, Post-credits scen...
# 28  [Lander, Governor, Current affairs, Mahatma Ga...
# 29  [Farmer, Government, Plan, Pradhan Mantri Awas...
# 30  [Donald Trump, Stimulus, Indian general electi...
# 31  [Sambit Patra, Muhammad Ali Jinnah, Kanhaiya K...
# 32  [Swaraj Party, Kapil Mishra, Protest, Yogi Adi...
# 33              [Silver, AirAsia, Aloe vera, Nitrate]
# 34           [Republic TV, Jansatta, Ban, BSE SENSEX]
# 35  [Cyclone, Tropical cyclone, Gabon, Côte d'Ivoire]
# 36  [Martyrs' Day (in India), Headquarters, Kerala...
# 37  [L'entrepôt RONA Québec, Gujarati language, Ro...
# 38  [Uttar Pradesh, Lok Sabha, Indian general elec...
# 39  [Kolkata Knight Riders, Shubman Gill, Andre Ru...
# 40  [Poland national football team, match, Sputnik...
# 41                    [Voting, ONLY, Quizlet, Profit]
# 42  [West Bengal Legislative Assembly, Tejashwi Ya...
# 43  [Natural environment, Air conditioning, High-p...
#
#                                   regions_of_interest  \
# 0   [[0, West Bengal], [0, Uttarakhand], [0, Uttar...
# 1   [[100, Tamil Nadu], [59, Kerala], [19, Karnata...
# 2   [[100, Bihar], [61, Jharkhand], [48, Tripura],...
# 3   [[100, Andhra Pradesh], [63, Jammu and Kashmir...
# 4   [[100, Bihar], [65, Daman and Diu], [54, Dadra...
# 5   [[100, Mizoram], [48, Nagaland], [45, Arunacha...
# 6   [[100, Daman and Diu], [88, Jharkhand], [83, G...
# 7   [[100, Rajasthan], [9, Haryana], [8, Delhi], [...
# 8   [[100, Chandigarh], [81, Karnataka], [58, Punj...
# 9   [[100, Tripura], [88, Goa], [86, Jammu and Kas...
# 10  [[100, Karnataka], [81, Tamil Nadu], [63, Raja...
# 11  [[100, Goa], [54, Andhra Pradesh], [50, Telang...
# 12  [[100, Daman and Diu], [92, Tripura], [82, Sik...
# 13  [[100, Kerala], [83, Tamil Nadu], [71, Punjab]...
# 14  [[100, Tamil Nadu], [76, Puducherry], [41, Ker...
# 15  [[100, Bihar], [14, Jharkhand], [11, Dadra and...
# 16  [[100, Jharkhand], [12, Bihar], [3, West Benga...
# 17  [[100, Bihar], [36, Jharkhand], [24, Delhi], [...
# 18  [[100, Kerala], [98, Goa], [96, Tamil Nadu], [...
# 19  [[100, Daman and Diu], [95, Dadra and Nagar Ha...
# 20  [[100, Tamil Nadu], [96, Nagaland], [96, Megha...
# 21  [[100, Nagaland], [79, Daman and Diu], [78, Da...
# 22  [[100, Sikkim], [92, Arunachal Pradesh], [89, ...
# 23  [[0, West Bengal], [0, Uttarakhand], [0, Uttar...
# 24  [[100, Arunachal Pradesh], [73, Jammu and Kash...
# 25  [[100, Sikkim], [28, Punjab], [20, Chandigarh]...
# 26  [[100, Daman and Diu], [92, Punjab], [79, Goa]...
# 27  [[100, Kerala], [89, Tamil Nadu], [88, Mizoram...
# 28  [[100, Arunachal Pradesh], [99, Daman and Diu]...
# 29  [[100, Uttar Pradesh], [95, Jharkhand], [65, B...
# 30  [[100, Nagaland], [100, Arunachal Pradesh], [8...
# 31  [[100, Telangana], [47, Jharkhand], [41, Bihar...
# 32  [[100, Delhi], [90, Goa], [76, Uttarakhand], [...
# 33  [[100, Jharkhand], [99, Uttarakhand], [98, Goa...
# 34  [[100, Delhi], [85, Goa], [82, Meghalaya], [80...
# 35  [[100, Goa], [68, Gujarat], [51, Delhi], [49, ...
# 36  [[100, Kerala], [81, Assam], [68, Odisha], [60...
# 37  [[100, Gujarat], [67, Chandigarh], [59, Punjab...
# 38  [[100, Bihar], [43, Jharkhand], [32, Tripura],...
# 39  [[100, Bihar], [37, Jharkhand], [25, Daman and...
# 40  [[100, Daman and Diu], [63, Arunachal Pradesh]...
# 41  [[100, Andhra Pradesh], [42, Tamil Nadu], [39,...
# 42  [[100, Bihar], [74, Arunachal Pradesh], [71, J...
# 43  [[0, West Bengal], [0, Uttarakhand], [0, Uttar...
#
#                                                Tweets
# 0   [RT @Rehanpawanist_: Hope you got an idea of s...
# 1                                                 NaN
# 2   [RT @YangerINC: The Bihar Poll story according...
# 3                                                 NaN
# 4   [RT @Kattar_Hindu11: And I was thinking that n...
# 5   [RT @kkoobap: watch bighit's family concert ha...
# 6                                                 NaN
# 7   [RT @ajaymaken: A good news from Urban Rajasth...
# 8                                                 NaN
# 9   [RT @LMcKirdy7: Fair to say Mitchell Starc was...
# 10  [RT @AnkitAk379: Hindu sentiments also matters...
# 11  [RT @CTRavi_BJP: Who will be the first to blam...
# 12  [RT @SathyanKolathur: I'm waiting for @RahulGa...
# 13                                                NaN
# 14  [RT @archanakalpathi: Just finished watching #...
# 15  [RT @knowthenation: #BiharElectionResults: Tre...
# 16  [@BaluSreevidya jharkhand is it bjp in one sea...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  [RT @TheParamGulati: You are an inspiration @u...
# 24                                                NaN
# 25                                                NaN
# 26  [RT @KTRTRS: This 19.8 MW plant is the most mo...
# 27  [@ExSecular @rautsanjay61 After the kind of vo...
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  [@MeghUpdates In 5-7 seats BJP is winning bcoz...
# 32                                                NaN
# 33  [RT @Aadhiraspeaks: This made my day..!! \nThi...
# 34  [RT @asjadnazir: The #Laxmii reviews are in &a...
# 35  [RT @RitaPanahi: ‘Islamists behead more than 5...
# 36                                                NaN
# 37  [RT @vivekagnihotri: Rona dhona has started. L...
# 38  [RT @MnshaP: Why is the hashtag #Nov10WithArna...
# 39  [RT @rishibagree: I was in Patna for 15 days. ...
# 40  [War ended and we win this War today ! This is...
# 41                                                NaN
# 42  [RT @OpIndia_com: The viral video of old woman...
# 43                                                NaN

# %%
df.to_pickle('step4_data.pkl')
