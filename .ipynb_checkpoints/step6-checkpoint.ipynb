# %% [markdown]
# #### Step6: Find Hashtags, Named Entities, Text with emojis etc from extracted text for text cues

# %%
file_name = 'step5_data.pkl'
df = pd.read_pickle(file_name)

# %%
import preprocessor as tweet_p
import re

# %%
tweet_p.set_options(tweet_p.OPT.URL,tweet_p.OPT.MENTION)

# %%
for i in df['Tweets']:
    try:
        for j in i:
            j = j.splitlines()
            for tweet in j:
                print(tweet_p.clean(tweet))
            print('_'*100)
    except:
        pass
# Out:
# RT : Hope you got an idea of students power
#
# Students Tho pettukovadhu😂👌
#
# #DubbakaBypolls • #DubbakaElections
# ____________________________________________________________________________________________________
# RT : Real change is in Telangana. has won #DubbakaBypolls by 1.5K+ margin. This is going to create earth quake.…
# ____________________________________________________________________________________________________
# RT : Hope you got an idea of students power
#
# Students Tho pettukovadhu😂👌
#
# #DubbakaBypolls • #DubbakaElections
# ____________________________________________________________________________________________________
# #BJP wins #DubbakaBypolls by a slender margin in Telangana.
#
# In #KarnatakaBypolls, BJP wins both #Sira and #RRNagar bypolls.
# ____________________________________________________________________________________________________
# Yes this is true
# ...

# %%
from emoji import UNICODE_EMOJI

# %%
def is_emoji(s):
    return s in UNICODE_EMOJI

# %%
s = '🙌'

# %%
is_emoji(s)
# Out:
# True

# %%
from nltk.tokenize import word_tokenize

# %%
text = " SidNaaz Craze and Burnol Trending together 😂🤣"
print(word_tokenize(text))
# Out:
# ['SidNaaz', 'Craze', 'and', 'Burnol', 'Trending', 'together', '😂🤣']

# %%
import gensim
all_stopwords = set(gensim.parsing.preprocessing.STOPWORDS)
#print(set(all_stopwords))

# %%
line = " #SidNaaz Craze and Burnol Trending together 😂🤣 !!"

# %%
#gather_details
line = word_tokenize(line)
exclamation_indices = []
emoji_indices = []
hashtag_indices = []
named_entities = {}

c = 0
for word_index in range(len(line)):
    if line[word_index] in all_stopwords:
        continue
    elif line[word_index].startswith('#'):
        hashtag_indices.append(word_index)
        
    elif line[word_index] == '!':
        exclamation_indices.append(word_index)
    
    elif is_emoji(line[word_index][0]) :
        emoji_indices.append(word_index)
      
print(exclamation_indices,emoji_indices, hashtag_indices)
# Out:
# [8, 9] [7] [0]

# %%
#new line with emojis on right without fullstops before emojis, less than 5 words
