# %%
file_name = 'final_ans.pkl'
sample_ans = pd.read_pickle(file_name)

# %%
sample_ans
# Out:
#                      title  popularity                                 Type  \
# 0           #ArnabGowswami   99.000000                              hashtag
# 1                  #BigSur   98.326336                              hashtag
# 2           #LudoOnNetflix   71.008720                              hashtag
# 3                Dhanteras   66.137120                            Festivity
# 4             NEET results   58.417323                 Entrance examination
# 5             Barack Obama   51.545378                  44th U.S. President
# 6        The Supreme Court   46.864313                                Court
# 7                   billie   46.379615                        Swedish actor
# 8        BTS PAVED THE WAY   45.638939                              hashtag
# 9        #RedmiNote9ProMax   43.699868                              hashtag
# 10         PM Kisan Yojana   42.118071                              hashtag
# ...

# %%
sample_ans.to_csv('final_sumission.csv')
